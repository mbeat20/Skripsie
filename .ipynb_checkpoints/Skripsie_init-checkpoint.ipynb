# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import SpectralClustering
from scipy.linalg import eigh
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN, MeanShift, estimate_bandwidth
import pandas as pd
from sklearn.metrics.pairwise import rbf_kernel
from sklearn.decomposition import PCA
from scipy.ndimage import gaussian_filter1d
from maad import sound
from sklearn.metrics.pairwise import euclidean_distances, polynomial_kernel, cosine_similarity, laplacian_kernel, linear_kernel
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.neighbors import kneighbors_graph
import seaborn as sns
from sklearn.mixture import GaussianMixture
# %matplotlib inline

# %%
start = 0
# duration = 300

audio_data, sampling_rate = librosa.load('../../Data/ElephantIsland2014/wav/20140123_110000_AWI251-01_AU0231_250Hz.wav', sr=250, offset=start)

duration = librosa.get_duration(y=audio_data, sr=sampling_rate)
duration
# Out:
# 300.0

# %%
plt.figure(figsize=(12, 4))
librosa.display.waveshow(audio_data, sr=sampling_rate)
plt.show()
# librosa.display.specshow(audio_data)
# plt.show

# %%
audio_data = librosa.effects.preemphasis(audio_data)

# window_length = 314
# hop_length = 85
# fft_size = 314
n_mels=80
window_length = 256
hop_length = 64
fft_size = 256

D = librosa.stft(audio_data, n_fft=fft_size, hop_length=hop_length, win_length=window_length, window='hann')
spectrogram = librosa.amplitude_to_db(np.abs(D))
power_spectrum=np.abs(D)**2

# Plot the spectrogram
plt.figure(figsize=(15, 5))
librosa.display.specshow(spectrogram, sr=sampling_rate, hop_length=hop_length, x_axis='time', y_axis='log', cmap='viridis')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.tight_layout()
plt.show()

# %%
mel_filter_bank = librosa.filters.mel(sr=sampling_rate, n_fft=fft_size, n_mels=n_mels)
mel_spectrum = np.dot(mel_filter_bank, power_spectrum)

# Step 7: Take the logarithm of the Mel spectrum
log_mel_spectrum = np.log(mel_spectrum + 1e-9)  # Add a small value to avoid log(0)
plt.figure(figsize=(15, 5))
librosa.display.specshow(log_mel_spectrum, sr=sampling_rate, hop_length=hop_length, x_axis='time', y_axis='mel', cmap='viridis')
plt.colorbar(format='%+2.0f dB')
plt.title('Log Mel Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Mel Frequency (Hz)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\librosa\display.py:1255: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   if __same_axes(x_axis, y_axis, axes.get_xlim(), axes.get_ylim()) and auto_aspect:

# %%
# filtered_audio = sound.select_bandwidth(audio_data, sampling_rate, fcut=(24,30), forder=5, ftype='bandpass')

# Sxx_filtered, tn_filtered, fn_filtered, ext_filtered = sound.spectrogram(filtered_audio, sampling_rate)
filtered_audio_1 = sound.select_bandwidth(audio_data, sampling_rate, fcut=(24, 30), forder=4, ftype='bandpass')

# # # Second bandpass filter: 60 to 70 Hz
filtered_audio_2 = sound.select_bandwidth(audio_data, sampling_rate, fcut=(40, 70), forder=4, ftype='bandpass')

# Combine the two filtered signals
combined_filtered_audio = filtered_audio_1 + filtered_audio_2

# # Generate the spectrogram of the combined filtered audio
Sxx_filtered, tn_combined, fn_combined, ext_filtered = sound.spectrogram(combined_filtered_audio, sampling_rate)


# Plot the spectrogram using matplotlib
plt.figure(figsize=(15, 5))
plt.imshow(Sxx_filtered, aspect='auto', extent=ext_filtered, origin='lower', cmap='viridis')
plt.colorbar(format='%+2.0f dB')
plt.title('Filtered Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.show()


# Apply noise reduction (e.g., spectral subtraction)
# reduced_noise_audio = sound.spectral_subtraction(filtered_audio, sampling_rate, n_fft=1024, hop_length=512)
# Sxx_denoised, tn_denoised, fn_denoised, ext_denoised = sound.spectrogram(reduced_noise_audio, sampling_rate)
# plt.figure(figsize=(15, 5))
# sound.plot_spectrogram(Sxx_denoised, tn_denoised, fn_denoised, ext=ext_denoised)
# plt.title('Spectrogram After Noise Reduction')
# plt.show(

# %%
num_mfcc = 10
# mfccs = librosa.feature.mfcc(y=audio_data, sr=sampling_rate, n_mfcc=num_mfcc, hop_length=hop_length, win_length=window_length)
# mffcs = librosa.feature.mfcc(y=mel_spectrum, n_fft=fft_size)
mfccs = librosa.feature.mfcc(S=Sxx_filtered, n_fft=fft_size, n_mfcc=num_mfcc)
mfccs_delta = librosa.feature.delta(mfccs)

mfccs_combined = np.vstack([mfccs,mfccs_delta])
delta2_mfccs = librosa.feature.delta(mfccs, order=2)
scaler_mfcc = StandardScaler()
scaler_delta = StandardScaler()

mfccs_scaled = scaler_mfcc.fit_transform(mfccs.T).T
delta_scaled = scaler_delta.fit_transform(mfccs_delta.T).T

mfccs_combined_scaled = np.vstack([mfccs_scaled, delta_scaled])
scaler_combined = StandardScaler()
mfccs_combined_scaled_scaled = scaler_combined.fit_transform(mfccs_combined_scaled.T).T

# Non-standardized MFCC coefficients
plt.figure(figsize=(15, 5))
librosa.display.specshow(mfccs, sr=sampling_rate, hop_length=hop_length, x_axis='time', cmap='coolwarm')
plt.colorbar(label='Non-Standardized MFCC Coefficients')
plt.title(f'Non-Standardized MFCC Spectrogram with {num_mfcc} Coefficients')
plt.xlabel('Time (s)')
plt.ylabel('MFCC Coefficients')
plt.tight_layout()
plt.show()

plt.figure(figsize=(15, 5))
librosa.display.specshow(mfccs_scaled, sr=sampling_rate, hop_length=hop_length, x_axis='time', cmap='coolwarm')
plt.colorbar(label='Standardized MFCC Coefficients')
plt.title(f'Standardized MFCC Spectrogram with {num_mfcc} Coefficients')
plt.xlabel('Time (s)')
plt.ylabel('MFCC Coefficients')
plt.tight_layout()
plt.show()

plt.figure(figsize=(15, 5))
librosa.display.specshow(mfccs_delta, sr=sampling_rate, hop_length=hop_length, x_axis='time', cmap='coolwarm')
plt.colorbar(label='Non-Standardized delta Coefficients')
plt.title(f'Non-Standardized MFCCs Delta with {num_mfcc} Coefficients')
plt.xlabel('Time (s)')
plt.ylabel('MFCC Delta Coefficients')
plt.tight_layout()
plt.show()

plt.figure(figsize=(15, 5))
librosa.display.specshow(delta_scaled, sr=sampling_rate, hop_length=hop_length, x_axis='time', cmap='coolwarm')
plt.colorbar(label='Standardized delta Coefficients')
plt.title(f'Standardized MFCCs Delta with {num_mfcc} Coefficients')
plt.xlabel('Time (s)')
plt.ylabel('MFCC Delta Coefficients')
plt.tight_layout()
plt.show()

plt.figure(figsize=(15, 5))
librosa.display.specshow(mfccs_combined, sr=sampling_rate, hop_length=hop_length, x_axis='time', cmap='coolwarm')
plt.colorbar(label='Non-standardized delta Coefficients')
plt.title(f'Non-Standardized MFCCs AND Delta coefficients with {num_mfcc} Coefficients')
plt.xlabel('Time (s)')
plt.ylabel('MFCC Delta Coefficients')
plt.tight_layout()
plt.show()

plt.figure(figsize=(15, 5))
librosa.display.specshow(mfccs_combined_scaled, sr=sampling_rate, hop_length=hop_length, x_axis='time', cmap='coolwarm')
plt.colorbar(label='Standardized delta Coefficients')
plt.title(f'Standardized MFCCs AND Delta coefficients with {num_mfcc} Coefficients')
plt.xlabel('Time (s)')
plt.ylabel('MFCC Delta Coefficients')
plt.tight_layout()
plt.show()

plt.figure(figsize=(15, 5))
librosa.display.specshow(mfccs_combined_scaled_scaled, sr=sampling_rate, hop_length=hop_length, x_axis='time', cmap='coolwarm')
plt.colorbar(label='Standardized delta Coefficients')
plt.title(f'Standardized (Twice) MFCCs AND Delta coefficients with {num_mfcc} Coefficients')
plt.xlabel('Time (s)')
plt.ylabel('MFCC Delta Coefficients')
plt.tight_layout()
plt.show()
# Standaradized MFCC coefficents
# Standardize the MFCC features


# Plot the standardized MFCCs

# %%
pca = PCA(n_components=12)  
mfccs_pca = pca.fit_transform(mfccs_combined_scaled.T)

plt.figure(figsize=(15, 5))
librosa.display.specshow(mfccs_pca.T, sr=sampling_rate, hop_length=hop_length, x_axis='time', cmap='coolwarm')
plt.colorbar(label='PCA MFCC Coefficients')
plt.title('Standardized and PCA-Transformed MFCC Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('MFCC Coefficients')
plt.tight_layout()
plt.show()

explained_variance = pca.explained_variance_ratio_
cumulative_variance = explained_variance.cumsum()

print("Explained variance by each component:", explained_variance)
print("Cumulative variance explained by the components:", cumulative_variance)

plt.figure(figsize=(8, 4))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', linestyle='--')
plt.title('Cumulative Variance Explained by PCA Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Variance Explained')
plt.grid(True)
plt.show()
# Out:
# Explained variance by each component: [4.35306732e-01 4.31415113e-01 5.49428051e-02 4.87920298e-02
#  1.15681140e-02 8.05888093e-03 5.36527377e-03 4.05609285e-03
#  2.45611948e-04 2.08833007e-04 2.12141943e-05 1.90030456e-05]
# Cumulative variance explained by the components: [0.43530673 0.86672185 0.92166465 0.97045668 0.98202479 0.99008368
#  0.99544895 0.99950504 0.99975065 0.99995949 0.9999807  0.9999997 ]

# %%
def clustering(X, affinity_matrix):

    # distance = euclidean_distances(X)
    # sigma = np.median(np.std(X, axis=0))
    # affinity_matrix = rbf_kernel(X, gamma=1/(2*(sigma**2)))
    # n = 1
    # affinity_matrix = kneighbors_graph(X, n_neighbors=n, mode='connectivity', include_self=True)
    # affinity_matrix = affinity_matrix.toarray()
    # print(affinity_matrix)
    # affinity_matrix = np.dot(X, X.T)
    # print(affinity_matrix)


    #Degree matrix
    degree_matrix = np.diag(np.sum(affinity_matrix, axis=1))
    epsilon = 1e-5  # Adjust this value as needed
    degree_matrix += np.eye(degree_matrix.shape[0]) * epsilon

    min_threshold = 1e-5  # Set a minimum threshold to avoid small values causing issues
    degree_matrix = np.clip(degree_matrix, min_threshold, None)

    sqrt_deg_matrix = np.diag(1.0 / np.sqrt(np.diag(degree_matrix)))
    norm_laplacian_matrix = np.eye(degree_matrix.shape[0]) - sqrt_deg_matrix @ affinity_matrix @ sqrt_deg_matrix

    #Eigenvalue decomp
    eig_values, eig_vectors = eigh(norm_laplacian_matrix)
    idx = eig_values.argsort()
    eig_values = eig_values[idx]
    eig_vectors = eig_vectors[:,idx]

    k = 7
    feature_vector = eig_vectors[:, :k]
    # feature_vector = StandardScaler().fit_transform(feature_vector)


    # Apply k-means clustering
    
    cluster = KMeans(n_clusters=3, n_init=20)
    # cluster = AgglomerativeClustering(n_clusters=3, linkage='ward')
    # cluster = DBSCAN(eps=0.2, min_samples=1)
#     cluster = GaussianMixture(n_components=3, covariance_type='full')
    # bandwidth = estimate_bandwidth(feature_vector, quantile=0.5)
    # cluster = MeanShift(bandwidth=bandwidth) #mean shift clustering - should use if k not known.
    labels = cluster.fit_predict(feature_vector)
    

    # print(labels)

    # time_axis = np.arange(len(labels)) * (duration / len(labels))  # Time in seconds
    time_axis = np.arange(len(labels)) * (duration / len(labels))

    # Convert to minutes and seconds

    # Plot the cluster labels over time
    plt.figure(figsize=(15, 5))
    plt.scatter(time_axis, labels, c=labels, cmap='viridis', s=10)
    plt.xlabel('Time (s)')
    plt.ylabel('Cluster Label')
    plt.xticks(np.arange(0, max(time_axis), 10))

    plt.show()

    silhouette = silhouette_score(X, labels)
    # calinski_harabasz = calinski_harabasz_score(X, labels)
    # davies_bouldin = davies_bouldin_score(X, labels)

    # params = [
    #         # ['Data used: ', X], 
            # ['Affinity matrix: ', affinity_matrix],
            # ['Clusters: ', cl],
    #         ['Silhouette: ', silhouette],
    #     ]
    print(silhouette)
     # Determine optimal number of eigenvectors (k) to use

# %%
# import matplotlib.pyplot as plt

# time_axis = np.arange(len(labels)) * (duration / len(labels))  # Time in seconds



# # Plot the cluster labels over time
# plt.figure(figsize=(15, 5))
# plt.scatter(time_axis, labels, c=labels, cmap='viridis', s=10)
# plt.xlabel('Time (s)')
# plt.ylabel('Cluster Label')
# plt.show()

# %%
X = mfccs_combined_scaled.T

sigma = np.median(np.std(X, axis=0))
affinity_matrix_rbf = rbf_kernel(X, gamma=1/(2*(sigma**2)))

affinity_matrix_dot = np.dot(X, X.T)

n = 5
affinity_matrix_neighbours = kneighbors_graph(X, n_neighbors=n, mode='connectivity', include_self=True)
affinity_matrix_neighbours = affinity_matrix_neighbours.toarray()

affinity_matrix_poly = polynomial_kernel(X, degree=3, gamma=1, coef0=1)

affinity_matrix_cos = cosine_similarity(X)

affinity_matrix_laplacian = laplacian_kernel(X, gamma=1/(2*sigma**2))

affinity_matrix_linear = linear_kernel(X)

# clustering(X, affinity_matrix_rbf)
clustering(X, affinity_matrix_dot)
# clustering(X, affinity_matrix_neighbours)
clustering(X, affinity_matrix_cos)
# clustering(X, affinity_matrix_poly)
clustering(X, affinity_matrix_linear)
# Out:
# 0.20453440114523974
# -0.06952668672362494
# 0.29474681284693693

# %%
# # cumulative_variance = np.cumsum(eig_values) / np.sum(eig_values)
#     plt.figure(figsize=(10, 6))
#     plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o')
#     plt.xlabel('Number of Eigenvectors')
#     plt.ylabel('Cumulative Variance Explained')
#     plt.title('Cumulative Variance Explained by Eigenvectors')
#     plt.grid(True)
#     plt.show()

#     # Experiment with different k values and evaluate clustering performance
#     best_k, best_silhouette = 0, -1
#     for k in range(2, 11):  # You can adjust the range of k
#         feature_vector = eig_vectors[:, :k]
#         labels = GaussianMixture(n_components=3, covariance_type='full').fit_predict(feature_vector)
#         silhouette = silhouette_score(feature_vector, labels)
#         print(f"k = {k}, Silhouette Score: {silhouette}")
#         if silhouette > best_silhouette:
#             best_silhouette, best_k = silhouette, k

#      # Use the best k for final clustering
#     print(f"Best k found: {best_k} with Silhouette Score: {best_silhouette}")
#     feature_vector = eig_vectors[:, :best_k]
#     cluster = GaussianMixture(n_components=3, covariance_type='full')
#     labels = cluster.fit_predict(feature_vector)

#     # Plot the cluster labels over time
#     time_axis = np.arange(len(labels)) * (duration / len(labels))
#     plt.figure(figsize=(15, 5))
#     plt.scatter(time_axis, labels, c=labels, cmap='viridis', s=10)
#     plt.xlabel('Time (s)')
#     plt.ylabel('Cluster Label')
#     plt.xticks(np.arange(0, max(time_axis), 10))
#     plt.show()

#     silhouette = silhouette_score(X, labels)
#     calinski_harabasz = calinski_harabasz_score(X, labels)
#     davies_bouldin = davies_bouldin_score(X, labels)
    # print(f"Final Silhouette Score: {silhouette}")
    # print(f"Calinski-Harabasz Index: {calinski_harabasz}")
    # print(f"Davies-Bouldin Index: {davies_bouldin}")

    # return labels
